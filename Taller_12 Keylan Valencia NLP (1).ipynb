# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #12: Análisis de sentimiento
# `Fecha de entrega: Mayo 27, 2021 (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %% [markdown]
# ###  `[25 pts]` Punto 1: Hacer análisis de sentimiento de los datos del anterior taller
# - Columna con el puntaje numérico del sentimiento
# - Pueden usar cualquiera de las librerias vistas en clase

# %%
#Instalación de Librerías 
# !pip install vaderSentiment
# !pip install textblob
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 0.24.1 requires scipy>=0.19.1, which is not installed.
# scikit-learn 0.24.1 requires threadpoolctl>=2.0.0, which is not installed.

# %%
#Se Importa el Archivo, la palabra clave de búsqueda en Bogotá era orientada a Human Rights Watch, esperando 
#algunos tweets en inglés, pero salieron muy pocos. 🤨

import pandas as pd
df_paro = pd.read_csv('C:/Users/KeylanRolandoValenci/Downloads/archivo_paro28m.csv')
df_paro.head()
# Out:
#                                                                                                                                                                                                                               tweets  \
# 0                                                                                                               Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/myefuQJ0oJ a través de @rcnradio
# 1  Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc17HW5
# 2                                                                                                             Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/XfvjfWq6uT https://t.co/n8dbr09y79
# ...

# %%
# Visualización de Columnas con el puntaje numérico del sentimiento

pd.set_option('display.max_colwidth', None)

df_paro['df_sense_vader'] = df_paro['texto_limpio'].apply(lambda val: vader.polarity_scores(val)['compound'])
df_paro['df_sense_TextBlob'] = df_paro['texto_limpio'].apply(lambda val: TextBlob(val).sentiment.polarity)

df_paro[['tweets', 'df_sense_vader', 'df_sense_TextBlob']]
# Out:
#                                                                                                                                                                                                                                                                                             tweets  \
# 0                                                                                                                                                                             Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/myefuQJ0oJ a través de @rcnradio
# 1                                                                Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc17HW5
# ...

# %%
df_paro.head()
# Out:
#                                                                                                                                                                                                                               tweets  \
# 0                                                                                                               Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/myefuQJ0oJ a través de @rcnradio
# 1  Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc17HW5
# 2                                                                                                             Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/XfvjfWq6uT https://t.co/n8dbr09y79
# ...

# %% [markdown]
# ###  `[25 pts]` Punto 2: ¿Cuál es el tuit más positivo y más negativo?

# %%
df_paro[['tweets','df_sense_vader']].sort_values('df_sense_vader').tail()

# Tweet mas positivo usando Vader 😣
#Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia
#en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el 
#Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc17HW5
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                     tweets  \
# 21                                                                                                                                                                       Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc17HW5
# ...

# %%
df_paro[['tweets','df_sense_TextBlob']].sort_values('df_sense_TextBlob').tail()

# Tweet mas positivo (Completamente neutral) usando TextBlob 😣
#La FLIP y la organización Human Rights Watch han insistido ante 
#la comunidad nacional e internacional en que jamás habían visto 
#en Colombia este grado de agresiones contra la prensa.\nhttps://t.co/KuGy4T9Syv
# Out:
#                                                                                                                                                                                                                                                                                                               tweets  \
# 26                                                                                                   La FLIP y la organización Human Rights Watch han insistido ante la comunidad nacional e internacional en que jamás habían visto en Colombia este grado de agresiones contra la prensa.\nhttps://t.co/KuGy4T9Syv
# 27                                                                                 Un artefacto militar, condenado por Human Rights Watch, y que ha tenido presencia en el paro nacional en Colombia. Así es Venom, la poderosa arma que utiliza el Escuadrón Móvil Antidisturbios (Esmad).\nhttps://t.co/IygXc1piND
# ...

# %%
df_paro[['tweets','df_sense_vader']].sort_values('df_sense_vader')

# Tweet mas Negativo usando Vader 😣
#denuncie las violaciones a los derechos humanos en COLOMBIA...\n\n
#REPORT VIOLATIONS OF HUMAN RIGHTS IN COLOMBIA
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                     tweets  \
# 15                                                                                                                            @POTUS denuncie las violaciones a los derechos humanos en COLOMBIA...\n\nREPORT VIOLATIONS OF HUMAN RIGHTS IN COLOMBIA...\n\n#SOSColombiaNosEstanMatando\n#SOSCali\n#SOSColombiaDDHH\n#SOSMEDELLIN\n#SOSBogota\n#SOSPortalAmericas\n#SOSColombiaDDHH https://t.co/EhJH4bQZJl
# ...

# %%
df_paro[['tweets','df_sense_TextBlob']].sort_values('df_sense_TextBlob')

# Tweet mas negativo usando TextBlob 😣
#Director de Human Rights Watch propone que Colombia reforme
#la Policía https://t.co/myefuQJ0oJ a través de @rcnradio
# Out:
#                                                                                                                                                                                                                                                                                                               tweets  \
# 0                                                                                                                                                                                               Director de Human Rights Watch propone que Colombia reforme la Policía https://t.co/myefuQJ0oJ a través de @rcnradio
# 33                                                                                                                                                                                                       Director Ejecutivo, División de las Américas\n*Human Rights Watch*\n#CIDHEnColombia https://t.co/9yZNLCqidF
# ...
